# %%
import pandas as pd
import sqlite3
import csv

# %%
cov19 = pd.read_csv("Data.csv")
cov19.dropna(inplace=True)
cov19 = cov19.rename(columns={'Entity': 'Country', 'Latitude': 'Lat' , 'Longitude': 'Long', 'Latitude': 'Lat',\
                              'Average temperature per year': 'Avg Temp per year', \
                              'Hospital beds per 1000 people': 'Beds per thousand', \
                              'Medical doctors per 1000 people': 'Doctors per thousand', \
                              'Population aged 65 and over (%)' : 'Percent Population Age over 65', \
                              'GDP/Capita': 'GDP per Capita'})

# %%
cov19
# Out:
#         Country Continent    Lat   Long  Avg Temp per year  Beds per thousand  \
# 15      Albania    Europe  41.15  20.17                 14               2.89
# 16      Albania    Europe  41.15  20.17                 14               2.89
# 17      Albania    Europe  41.15  20.17                 14               2.89
# 18      Albania    Europe  41.15  20.17                 14               2.89
# 19      Albania    Europe  41.15  20.17                 14               2.89
# ...         ...       ...    ...    ...                ...                ...
# 38464  Zimbabwe    Africa -19.02  29.15                 20               1.70
# 38465  Zimbabwe    Africa -19.02  29.15                 20               1.70
# 38466  Zimbabwe    Africa -19.02  29.15                 20               1.70
# 38467  Zimbabwe    Africa -19.02  29.15                 20               1.70
# 38468  Zimbabwe    Africa -19.02  29.15                 20               1.70
#
#        Doctors per thousand  GDP per Capita  Population  Median age  \
# 15                     1.29          5353.2     2873457          38
# 16                     1.29          5353.2     2873457          38
# 17                     1.29          5353.2     2873457          38
# 18                     1.29          5353.2     2873457          38
# 19                     1.29          5353.2     2873457          38
# ...                     ...             ...         ...         ...
# 38464                  0.08          1464.0    16529904          19
# 38465                  0.08          1464.0    16529904          19
# 38466                  0.08          1464.0    16529904          19
# 38467                  0.08          1464.0    16529904          19
# 38468                  0.08          1464.0    16529904          19
#
#        Percent Population Age over 65        Date  Daily tests    Cases  \
# 15                                 14  2020-03-11         43.0     12.0
# 16                                 14  2020-03-12        141.0     23.0
# 17                                 14  2020-03-13        159.0     33.0
# 18                                 14  2020-03-14         48.0     38.0
# 19                                 14  2020-03-15         27.0     42.0
# ...                               ...         ...          ...      ...
# 38464                               3  2021-02-21       1212.0  35796.0
# 38465                               3  2021-02-22       1643.0  35862.0
# 38466                               3  2021-02-23       1873.0  35910.0
# 38467                               3  2021-02-24       1804.0  35960.0
# 38468                               3  2021-02-25       2965.0  35994.0
#
#        Deaths
# 15        1.0
# 16        1.0
# 17        1.0
# 18        1.0
# 19        1.0
# ...       ...
# 38464  1436.0
# 38465  1441.0
# 38466  1448.0
# 38467  1456.0
# 38468  1458.0
#
# [28869 rows x 15 columns]

# %%
con = sqlite3.connect("cov19.db")
cur=con.cursor()

# %% [markdown]
# Create smaller databases, such as Country, Continent

# %%
cur.execute('''CREATE TABLE Continents( \
    Id INT, \
    Continent CHAR UNIQUE, \
    PRIMARY KEY (Id))''')
con.commit()

# %%
cur.execute('''CREATE TABLE Countries( \
    Id INT, \
    Country CHAR UNIQUE,\
    Cont_Id INT, \
    Lat FLOAT(24), \
    Long FLOAT(24), \
    "Avg Temp per year" INT, \
    "Beds per thousand" FLOAT(24), \
    "Doctors per thousand" FLOAT(24), \
    "GDP per Capita" FLOAT(24), \
    Population INT, \
    "Median Age" INT, \
    "Percent Population Age over 65" INT, \
    PRIMARY KEY (Id), \
    FOREIGN KEY (Cont_Id) REFERENCES Continents(Id))''')
con.commit()
print(cur.fetchall())
# Out:
# []

# %%
cur.execute('''CREATE TABLE Cases( \
    Id INT, \
    Country_Id INT, \
    Date, \
    "Daily tests" FLOAT(24),\
    Cases FLOAT(24),\
    Deaths FLOAT(24),\
    PRIMARY KEY (Id),\
    FOREIGN KEY (Country_Id) REFERENCES Countries(Id))''')
con.commit()

# %%
df_cont = pd.DataFrame(cov19["Continent"].unique(), columns=["Continent"])
df_cont['Id']=pd.factorize(df_cont['Continent'])[0]
df_cont=df_cont[['Id','Continent']]

# %%
df_cont
# Out:
#    Id      Continent
# 0   0         Europe
# 1   1         Africa
# 2   2  South America
# 3   3        Oceania
# 4   4           Asia
# 5   5  North America

# %%
df_cont.to_sql("Continents", con, if_exists="append", index=False)
con.commit
# Out:
# <function Connection.commit>

# %%
pd.read_sql_query('''SELECT * FROM Continents''',con)
# Out:
#    Id      Continent
# 0   0         Europe
# 1   1         Africa
# 2   2  South America
# 3   3        Oceania
# 4   4           Asia
# 5   5  North America

# %%
cov19['Country'].nunique()
# Out:
# 104

# %%
df_country = cov19.drop(columns=['Date','Daily tests','Cases','Deaths']).drop_duplicates()

# %%
df_country['Cont_Id']=pd.factorize(df_country['Continent'])[0]
df_country['Id']=pd.factorize(df_country['Country'])[0]
df_country=df_country[['Id','Country','Cont_Id','Lat','Long','Avg Temp per year',\
                      'Beds per thousand','Doctors per thousand','GDP per Capita','Population','Median age',\
                      'Percent Population Age over 65']]

# %%
df_country.to_sql("Countries", con, if_exists="append", index=False)
con.commit
# Out:
# C:\Users\user\ansel\lib\site-packages\pandas\core\generic.py:2789: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
# <function Connection.commit>

# %%
pd.read_sql_query('''SELECT * FROM Countries''',con)
# Out:
#       Id        Country  Cont_Id    Lat    Long  Avg Temp per year  \
# 0      0        Albania        0  41.15   20.17                 14
# 1      1        Algeria        1  28.03    1.66                 25
# 2      2      Argentina        2 -38.42  -63.62                 14
# 3      3        Armenia        0  40.07   45.04                 11
# 4      4      Australia        3 -25.27  133.78                 22
# ..   ...            ...      ...    ...     ...                ...
# 99    99  United States        5  37.09  -95.71                 11
# 100  100        Uruguay        2 -32.52  -55.77                 16
# 101  101        Vietnam        4  14.06  108.28                 25
# 102  102         Zambia        1 -13.13   27.85                 21
# 103  103       Zimbabwe        1 -19.02   29.15                 20
#
#      Beds per thousand  Doctors per thousand  GDP per Capita  Population  \
# 0                 2.89                  1.29          5353.2     2873457
# 1                 1.90                  1.83          3974.0    41318142
# 2                 5.00                  3.91          9912.3    44271041
# 3                 4.20                  2.80          4622.7     2930450
# 4                 3.84                  3.50         55060.3    24598933
# ..                 ...                   ...             ...         ...
# 99                2.77                  2.57         65297.5   325719178
# 100               2.80                  3.74         16190.1     3456750
# 101               2.60                  0.82          2715.3    95540800
# 102               2.00                  0.09          1305.1    17094130
# 103               1.70                  0.08          1464.0    16529904
#
#      Median Age  Percent Population Age over 65
# 0            38                              14
# 1            29                               6
# 2            31                              11
# 3            35                              11
# 4            37                              16
# ..          ...                             ...
# 99           38                              16
# 100          35                              15
# 101          32                               7
# 102          17                               2
# 103          19                               3
#
# [104 rows x 12 columns]

# %%
cur.execute('''DROP TABLE Continents''')

# %%
df_cases = cov19[['Country','Date','Daily tests','Cases','Deaths']]
df_cases['Country_Id']=pd.factorize(df_cases['Country'])[0]
df_cases['Id']=list(range(0,len(df_cases)))
df_cases = df_cases[['Id','Country_Id','Date','Daily tests','Cases','Deaths']]
# Out:
# C:\Users\user\ansel\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\user\ansel\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_cases
# Out:
#           Id  Country_Id        Date  Daily tests    Cases  Deaths
# 15         0           0  2020-03-11         43.0     12.0     1.0
# 16         1           0  2020-03-12        141.0     23.0     1.0
# 17         2           0  2020-03-13        159.0     33.0     1.0
# 18         3           0  2020-03-14         48.0     38.0     1.0
# 19         4           0  2020-03-15         27.0     42.0     1.0
# ...      ...         ...         ...          ...      ...     ...
# 38464  28864         103  2021-02-21       1212.0  35796.0  1436.0
# 38465  28865         103  2021-02-22       1643.0  35862.0  1441.0
# 38466  28866         103  2021-02-23       1873.0  35910.0  1448.0
# 38467  28867         103  2021-02-24       1804.0  35960.0  1456.0
# 38468  28868         103  2021-02-25       2965.0  35994.0  1458.0
#
# [28869 rows x 6 columns]

# %%
df_cases.to_sql("Cases", con, if_exists="append", index=False)
con.commit
# Out:
# C:\Users\user\ansel\lib\site-packages\pandas\core\generic.py:2789: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
# <function Connection.commit>

# %%
pd.read_sql_query('''SELECT * FROM Cases''',con)
# Out:
#           Id  Country_Id        Date  Daily tests    Cases  Deaths
# 0          0           0  2020-03-11         43.0     12.0     1.0
# 1          1           0  2020-03-12        141.0     23.0     1.0
# 2          2           0  2020-03-13        159.0     33.0     1.0
# 3          3           0  2020-03-14         48.0     38.0     1.0
# 4          4           0  2020-03-15         27.0     42.0     1.0
# ...      ...         ...         ...          ...      ...     ...
# 28864  28864         103  2021-02-21       1212.0  35796.0  1436.0
# 28865  28865         103  2021-02-22       1643.0  35862.0  1441.0
# 28866  28866         103  2021-02-23       1873.0  35910.0  1448.0
# 28867  28867         103  2021-02-24       1804.0  35960.0  1456.0
# 28868  28868         103  2021-02-25       2965.0  35994.0  1458.0
#
# [28869 rows x 6 columns]

# %%
cur.execute('''SELECT Country FROM Countries \
    WHERE Id = ( \
        SELECT Country_Id FROM Cases \
        WHERE 'Cases' > 'Deaths')''')
print(cur.fetchone())
# Out:
# None

# %%
# Out:
# (33,)
